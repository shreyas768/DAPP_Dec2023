# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\shrey\Desktop\DAPP_Aug2023\DATA\Airplane_Crashes_and_Fatalities_Since_1908.csv")
df.sample(15)
# Out:
#             Date   Time                           Location  \
# 350   10/03/1934    NaN             Near Winton, Australia
# 2406  08/25/1969    NaN                     Sucre, Ecuador
# 480   11/26/1937    NaN            Croydon, United Kingdom
# 997   11/27/1947  04:20  Montenegrin Mountains, Yugoslavia
# 2631  10/31/1972  18:00         Near My Tho, South Vietnam
# 1806  02/05/1960  07:20                Cochabamba, Bolivia
# 4877  07/23/2014  19:06                     Magong, Taiwan
# 4272  08/02/2000  08:45                    Cubatao, Brazil
# 2974  10/22/1978    NaN       Off Bellona, Solomon Islands
# 2955  06/23/1978    NaN         Saint John's, Newfoundland
# 3789  11/30/1992  21:20               Near Harlem, Montana
# 2042  07/27/1963  01:50     Off Bandra, Maharashtra, India
# 828   11/22/1945  10:00              White's Farm, England
# 3744  04/22/1992  11:09          Perris Valley, California
# 4379  07/01/2002  23:36                Uberlingen, Germany
#
#                                                Operator    Flight #  \
# 350                                              Qantas         NaN
# 2406                                                TAO         NaN
# 480                                  Deutsche Lufthansa         NaN
# 997                               JAT Yugoslav Airlines         NaN
# 2631                               Military - U.S. Army         NaN
# 1806                              Lloyd Aereo Boliviano         NaN
# 4877                                  TransAsia Airways         222
# 4272                          Air taxi - Lider Air Taxi         NaN
# 2974                           Solomon Islands Airlines         NaN
# 2955                                    Gander Aviation         NaN
# 3789  Military - U.S. Air Force / Military - U.S. Ai...         NaN
# 2042                               United Arab Airlines         869
# 828                           Military -Royal Air Force         NaN
# 3744                             Perris Valley Aviation         NaN
# 4379        Bashkirian Airlines / DHL Worldwide Express  2937 / 611
#
#                                            Route  \
# 350                                          NaN
# 2406                                         NaN
# 480                                          NaN
# 997                            Zagreb - Titograd
# 2631                                         NaN
# 1806                         Cochabamba - La Paz
# 4877                          Kaohsiung - Magong
# 4272                        Cubatao - Navegantes
# 2974                                         NaN
# 2955                Saint John's - Saint Anthony
# 3789                                         NaN
# 2042                            Bangkok - Bombay
# 828                          Merryfield - Bombay
# 3744                                       Local
# 4379  Moscow-Munich-Barcelona / Bahrain/Brussels
#
#                                        AC Type     Registration  \
# 350                        de Havilland DH-50A           VH-UHE
# 2406                             Douglas C-47B           HC-ALK
# 480                              Junkers JU-52           D-AGAV
# 997                               Lisunov LI-2           YU-BAD
# 2631          Boeing Vertol CH-47 (helicopter)              NaN
# 1806                              Douglas DC-4           CP-609
# 4877                                ATR 72-500          B-22810
# 4272                             Sikorsky S-76           PT-HRD
# 2974           Britten Norman BN-2A Trislander           H4-AAC
# 2955                       Beech Queen Air A80           C-GGAL
# 3789          Lockheed C-141B / Lockheed C141B    650255/660142
# 2042                     de Havilland Comet 4C           SU-ALD
# 828              Consolidated LB-30A Liberator            KH126
# 3744  de Havilland Canada DHC-6 Twin Otter 200           N141PV
# 4379      Tupolev TU-154M / Boeing B-757-23APF  RA85816/A9C-DHL
#
#                  cn/ln  Aboard  Aboard Passangers  Aboard Crew  Fatalities  \
# 350                  4     3.0                2.0          1.0         3.0
# 2406       15777/27222     1.0                0.0          4.0         1.0
# 480               4023     3.0                0.0          3.0         3.0
# 997         184 270 09    22.0               19.0          3.0        22.0
# 2631               NaN    22.0                NaN          NaN        22.0
# 1806             10510    59.0               55.0          4.0        59.0
# 4877               642    58.0               54.0          4.0        48.0
# 4272               NaN     6.0                5.0          1.0         6.0
# 2974              0613    11.0                NaN          NaN        11.0
# 2955            LD-233    10.0                8.0          2.0        10.0
# 3789       6106 / 6168    13.0                0.0         13.0        13.0
# 2042             06441    63.0               55.0          8.0        63.0
# 828                NaN    27.0               22.0          5.0        27.0
# 3744               141    22.0               20.0          2.0        16.0
# 4379  1006 / 24635/258    71.0               57.0         14.0        71.0
#
#       Fatalities Passangers  Fatalities Crew  Ground  \
# 350                     2.0              1.0     0.0
# 2406                    0.0              1.0     0.0
# 480                     0.0              3.0     0.0
# 997                    19.0              3.0     0.0
# 2631                    NaN              NaN     0.0
# 1806                   55.0              4.0     0.0
# 4877                   44.0              4.0     0.0
# 4272                    5.0              1.0     0.0
# 2974                    NaN              NaN     0.0
# 2955                    8.0              2.0     0.0
# 3789                    0.0             13.0     0.0
# 2042                   55.0              8.0     0.0
# 828                    22.0              5.0     0.0
# 3744                   14.0              2.0     0.0
# 4379                   57.0             14.0     0.0
#
#                                                 Summary
# 350   Crashed after in-flight loss of control, possi...
# 2406  The cargo plane crashed under unknown circumst...
# 480   Engine failure on takeoff caused the cargo pla...
# 997   The aircraft crashed and burned 2 miles from T...
# 2631  Shot down by enemy fire over the Mekong Delta ...
# 1806  Few minutes after takeoff and reaching an alti...
# 4877  The passenger plane crashed into residential b...
# 4272  The helicopter exploded and crashed from a hei...
# 2974                                                NaN
# 2955  Crashed in heavy fog while attempting to take ...
# 3789  The two aircraft on a training mission and ref...
# 2042  The aircraft crashed into the Arabian Sea whil...
# 828   The aircraft crashed into a hill shortly after...
# 3744  The plane, carrying parachutists, lost power a...
# 4379  The airliner and cargo plane collided over sou...

# %%
df['Route'].value_counts().head(20)
# Out:
# Route
# Training                      92
# Sightseeing                   31
# Test flight                   22
# Sao Paulo - Rio de Janeiro     7
# Test                           6
# Rio de Janeiro - Sao Paulo     5
# Paris - London                 4
# Sao Paulo - Porto Alegre       4
# Huambo - Luanda                4
# Bogota - Barranquilla          4
# Tallinn - Helsinki             4
# Villavicencio - Mitu           4
# Barranquilla - Bogota          4
# Demonstration                  4
# Croydon - Paris                4
# Paris - Croydon                3
# Honolulu - San Francisco       3
# London - Paris                 3
# Bangkok - Hong Kong            3
# Strasbourg - Paris             3
# Name: count, dtype: int64

# %%
df['Route'].replace('Test','Test flight',inplace=True)

# %%
df['Route'].value_counts().head(20)
# Out:
# Route
# Training                      92
# Sightseeing                   31
# Test flight                   28
# Sao Paulo - Rio de Janeiro     7
# Rio de Janeiro - Sao Paulo     5
# Paris - London                 4
# Sao Paulo - Porto Alegre       4
# Huambo - Luanda                4
# Bogota - Barranquilla          4
# Tallinn - Helsinki             4
# Villavicencio - Mitu           4
# Barranquilla - Bogota          4
# Demonstration                  4
# Croydon - Paris                4
# Paris - Croydon                3
# Honolulu - San Francisco       3
# London - Paris                 3
# Bangkok - Hong Kong            3
# Strasbourg - Paris             3
# Barrow - Wainwright            3
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4967 entries, 0 to 4966
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   4967 non-null   object
#  1   Time                   3457 non-null   object
#  2   Location               4963 non-null   object
#  3   Operator               4957 non-null   object
#  4   Flight #               1315 non-null   object
#  5   Route                  4192 non-null   object
#  6   AC Type                4952 non-null   object
#  7   Registration           4694 non-null   object
#  8   cn/ln                  4299 non-null   object
#  9   Aboard                 4949 non-null   float64
#  10  Aboard Passangers      4738 non-null   float64
#  11  Aboard Crew            4741 non-null   float64
#  12  Fatalities             4959 non-null   float64
#  13  Fatalities Passangers  4725 non-null   float64
#  14  Fatalities Crew        4726 non-null   float64
#  15  Ground                 4926 non-null   float64
#  16  Summary                4903 non-null   object
# dtypes: float64(7), object(10)
# memory usage: 659.8+ KB

# %%
df['Location'] = df['Location'].astype(str)

# %%
df['Location'] = df['Location'].apply(lambda x:x.split(',')[-1])

# %%
df.sample(5)
# Out:
#             Date   Time     Location                  Operator Flight #  \
# 4941  12/31/2017  12:16   Costa Rica                 Naure Air      NaN
# 3023  08/29/1979  00:26       Russia                  Aeroflot      NaN
# 1814  04/05/1960  14:39    Nicaragua                    Lanica      NaN
# 4311  04/28/2001  05:15    Argentina  Private - Techint  group      NaN
# 1011  01/13/1948  04:36     Maryland         Eastern Air Lines      572
#
#                            Route                     AC Type Registration  \
# 4941     Punta Islita - San Jose   Cessna 208B Grand Caravan       TI-BEI
# 3023              \tKiev - Kazan              Tupolev TU-124   CCCP-45038
# 1814             Siuna - Bonanza         Curtiss C-46A-40-CU       AN-AIN
# 4311  San Fernando - El Calafate  Cessna  208B Grand Caravan       LV-WSC
# 1011   Atlanta - Washington D.C.           Douglas DC-3-201F      NC28384
#
#           cn/ln  Aboard  Aboard Passangers  Aboard Crew  Fatalities  \
# 4941  208B-0900    12.0               10.0          2.0        12.0
# 3023    3351003    63.0               58.0          5.0        63.0
# 1814      26945    18.0               14.0          4.0         2.0
# 4311  208B-0580    10.0                8.0          2.0        10.0
# 1011       4092     9.0                6.0          3.0         5.0
#
#       Fatalities Passangers  Fatalities Crew  Ground  \
# 4941                   10.0              2.0     0.0
# 3023                   58.0              5.0     0.0
# 1814                    1.0              1.0     0.0
# 4311                    8.0              2.0     0.0
# 1011                    3.0              2.0     0.0
#
#                                                 Summary
# 4941  The passenger plane crashed 10 minutes after t...
# 3023  The aircraft lost control went into a spin and...
# 1814  Flew into a hill shortly after taking off. Eng...
# 4311  The aircraft crashed into rugged farm land, 12...
# 1011  The aircraft crashed during approach, 5.2 mile...

# %%
df['Location'].value_counts().head(25)
# Out:
# Location
#  Russia         253
#  Brazil         170
#  Colombia       149
#  France         123
#  Canada         121
#  California     115
#  Alaska         101
#  India          101
#  England        100
#  Indonesia       94
#  China           91
#  Italy           84
#  Mexico          83
#  Germany         77
#  Philippines     68
#  USSR            67
#  Australia       62
#  Spain           58
#  New York        55
#  Venezuela       54
#  Peru            54
#  Texas           47
#  Bolivia         44
#  Iran            43
#  Afghanistan     41
# Name: count, dtype: int64

# %%
df['Year'] = df['Date'].str[-4:]

# %%
df.sample()
# Out:
#            Date   Time Location Operator Flight #               Route  \
# 918  12/25/1946  17:00    China     CNAC      115  Chunking - Shanghi
#
#           AC Type Registration cn/ln  Aboard  Aboard Passangers  Aboard Crew  \
# 918  Curtiss C-47          NaN   NaN    34.0               31.0          3.0
#
#      Fatalities  Fatalities Passangers  Fatalities Crew  Ground  \
# 918        13.0                   10.0              3.0     3.0
#
#                                                Summary  Year
# 918  Crashed after a failed landing attempt at Kian...  1946

# %%
df['Month'] = df['Date'].str[:2]

# %%
df.sample(5)
# Out:
#             Date   Time        Location                   Operator Flight #  \
# 3396  12/25/1986  12:30    Saudi Arabia              Iraqi Airways      NaN
# 2376  03/08/1969    NaN  Atlantic Ocean  Continental Air Transport      NaN
# 2080  03/10/1964  08:22     Massachutes      Slick Airways - Cargo       12
# 4566  03/31/2006  17:39          Brazil                   Team Air     6865
# 3546  07/19/1989  11:02            USSR                   Aeroflot      NaN
#
#                                        Route            AC Type Registration  \
# 3396                         Baghdad - Amman  Boeing B-737-270C       YI-AGJ
# 2376     Halifax, NS - Santa Maria, Portugal       Douglas DC-4        N3821
# 2080        New York - Winsor Locks - Boston       Douglas DC-4         N384
# 4566                  Macaé - Rio de Janeiro    Let L410UVP-E20       PT-FSE
# 3546  Observation flight out of Cape Schmidt      Antonov AN-26   CCCP-26685
#
#        cn/ln  Aboard  Aboard Passangers  Aboard Crew  Fatalities  \
# 3396   21183   106.0               91.0         15.0        63.0
# 2376   10356     3.0                0.0          3.0         3.0
# 2080   18379     3.0                0.0          3.0         3.0
# 4566  912532    19.0               17.0          2.0        19.0
# 3546    8805    10.0                6.0          4.0        10.0
#
#       Fatalities Passangers  Fatalities Crew  Ground  \
# 3396                   60.0              3.0     0.0
# 2376                    0.0              3.0     0.0
# 2080                    0.0              3.0     0.0
# 4566                   17.0              2.0     0.0
# 3546                    6.0              4.0     0.0
#
#                                                 Summary  Year Month
# 3396  Hijacking.  While on a flight from Baghdad to ...  1986    12
# 2376  The cargo plane went missing en route between ...  1969    03
# 2080  While on approach, the cargo plane suddenly pi...  1964    03
# 4566  Twenty minutes after taking off from Macaé, th...  2006    03
# 3546  Crashed into costal cliffs while on an ice obs...  1989    07

# %%
#get years with most crashes

# %%
#get aircraft type with most crashes

# %%
#create a column with number of survivors

# %%
#get me number of crashes with zero survivors

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\shrey\Desktop\DAPP_Aug2023\DATA\Airplane_Crashes_and_Fatalities_Since_1908.csv")
df.sample(15)
# Out:
#             Date   Time                    Location  \
# 1770  08/14/1959  22:14           Karachi, Pakistan
# 4210  09/14/1999  23:47               Girona, Spain
# 1336  09/06/1952  15:40  Near Farnsborough, England
# 3796  01/06/1993  19:20               Paris, France
# 1564  04/18/1956    NaN           Parintins, Brazil
# 2979  11/19/1978  11:00             Near Leh, India
# 1617  04/15/1957  07:53              Merida, Mexico
# 1453  04/13/1954  13:10               Batuco, Chile
# 3093  01/20/1981  11:27         Spokane, Washington
# 587   10/22/1940    NaN             Osijek, Croatia
# 3114  06/26/1981  18:11          Nailstone, England
# 1754  04/23/1959  09:46                 Van, Turkey
# 1931  01/27/1962  18:17            Batataevka, USSR
# 832   12/18/1945  10:10        Voksenkollen, Norway
# 1877  02/15/1961  10:05      Near Brussels, Belgium
#
#                              Operator Flight #  \
# 1770  Pakistan International Airlines      NaN
# ...

# %%
df['Route'].value_counts().head(20)
# Out:
# Route
# Training                      92
# Sightseeing                   31
# Test flight                   22
# Sao Paulo - Rio de Janeiro     7
# Test                           6
# Rio de Janeiro - Sao Paulo     5
# Paris - London                 4
# Sao Paulo - Porto Alegre       4
# Huambo - Luanda                4
# Bogota - Barranquilla          4
# Tallinn - Helsinki             4
# Villavicencio - Mitu           4
# Barranquilla - Bogota          4
# Demonstration                  4
# Croydon - Paris                4
# Paris - Croydon                3
# Honolulu - San Francisco       3
# London - Paris                 3
# Bangkok - Hong Kong            3
# Strasbourg - Paris             3
# Name: count, dtype: int64

# %%
df['Route'].replace('Test','Test flight',inplace=True)

# %%
df['Route'].value_counts().head(20)
# Out:
# Route
# Training                      92
# Sightseeing                   31
# Test flight                   28
# Sao Paulo - Rio de Janeiro     7
# Rio de Janeiro - Sao Paulo     5
# Paris - London                 4
# Sao Paulo - Porto Alegre       4
# Huambo - Luanda                4
# Bogota - Barranquilla          4
# Tallinn - Helsinki             4
# Villavicencio - Mitu           4
# Barranquilla - Bogota          4
# Demonstration                  4
# Croydon - Paris                4
# Paris - Croydon                3
# Honolulu - San Francisco       3
# London - Paris                 3
# Bangkok - Hong Kong            3
# Strasbourg - Paris             3
# Barrow - Wainwright            3
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4967 entries, 0 to 4966
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   4967 non-null   object
#  1   Time                   3457 non-null   object
#  2   Location               4963 non-null   object
#  3   Operator               4957 non-null   object
#  4   Flight #               1315 non-null   object
#  5   Route                  4192 non-null   object
#  6   AC Type                4952 non-null   object
#  7   Registration           4694 non-null   object
#  8   cn/ln                  4299 non-null   object
#  9   Aboard                 4949 non-null   float64
#  10  Aboard Passangers      4738 non-null   float64
#  11  Aboard Crew            4741 non-null   float64
#  12  Fatalities             4959 non-null   float64
#  13  Fatalities Passangers  4725 non-null   float64
# ...

# %%
df['Location'] = df['Location'].astype(str)

# %%
df['Location'] = df['Location'].apply(lambda x:x.split(',')[-1])

# %%
df.sample(5)
# Out:
#             Date   Time     Location                   Operator Flight #  \
# 2782  03/20/1975  23:15   Washington  Military - U.S. Air Force      NaN
# 3205  04/16/1983    NaN        Sudan                Air Liberia      NaN
# 4668  07/07/2008  03:50     Colombia        Centurian Air Cargo      NaN
# 491   02/05/1938    NaN       Russia                      TsAGI      NaN
# 3308  03/28/1985  09:50     Colombia                     SATENA      NaN
#
#                                             Route  \
# 2782                            Clark AFB - Japan
# 3205                            Khartoum-Monrovia
# 4668                 Bogota, Colombia - Miami, FL
# 491                             Moscow - Murmansk
# 3308  Bogota - San Vicente del Caguán - Florencia
#
#                                  AC Type Registration      cn/ln  Aboard  \
# 2782             Lockheed C-141A (L.300)      64-0641       6054    16.0
# 3205  Hawker Siddeley HS-748-329 Srs. 2A       EL-AIH       1755     9.0
# ...

# %%
df['Location'].value_counts().head(25)
# Out:
# Location
#  Russia         253
#  Brazil         170
#  Colombia       149
#  France         123
#  Canada         121
#  California     115
#  Alaska         101
#  India          101
#  England        100
#  Indonesia       94
#  China           91
#  Italy           84
#  Mexico          83
#  Germany         77
#  Philippines     68
#  USSR            67
#  Australia       62
#  Spain           58
#  New York        55
#  Venezuela       54
#  Peru            54
#  Texas           47
#  Bolivia         44
#  Iran            43
#  Afghanistan     41
# Name: count, dtype: int64

# %%
df['Year'] = df['Date'].str[-4:]

# %%
df.sample()
# Out:
#             Date Time Location          Operator Flight #  \
# 3805  02/28/1993  NaN   Taiwan  Formosa Airlines      NaN
#
#                      Route          AC Type Registration cn/ln  Aboard  \
# 3805  Taipei-Iles Orchides  Dornier 228-201      B-12238   111     6.0
#
#       Aboard Passangers  Aboard Crew  Fatalities  Fatalities Passangers  \
# 3805                4.0          2.0         6.0                    4.0
#
#       Fatalities Crew  Ground  \
# 3805              2.0     0.0
#
#                                                 Summary  Year
# 3805  The aircraft disappeared shortly before it was...  1993

# %%
df['Month'] = df['Date'].str[:2]

# %%
df.sample(3)
# Out:
#             Date   Time     Location         Operator Flight #  \
# 1566  05/15/1956    NaN        Nepal  Indian Airlines      NaN
# 1933  02/25/1962    NaN    Venezuela           Avensa      NaN
# 2825  02/08/1976  10:44   California  Mercer Airlines      NaN
#
#                    Route         AC Type Registration  cn/ln  Aboard  \
# 1566  Shimla - Kathmandu    Douglas DC-3       VT-DBA  13165    31.0
# 1933   Porlamar - Cumana  Fairchild F-27     YV-C-EVH   0012    23.0
# 2825   Burbank - Ontario    Douglas DC-6       N901MA  36326     6.0
#
#       Aboard Passangers  Aboard Crew  Fatalities  Fatalities Passangers  \
# 1566               28.0          3.0        14.0                   14.0
# 1933               20.0          3.0        23.0                   20.0
# 2825                1.0          5.0         3.0                    1.0
#
#       Fatalities Crew  Ground  \
# 1566              0.0     1.0
# 1933              3.0     0.0
# 2825              2.0     0.0
#
# ...

# %%
#get years with most crashes
df['Year'].value_counts().head(10)
# Out:
# Year
# 1946    88
# 1989    83
# 1947    82
# 1948    77
# 1962    77
# 1972    77
# 1951    75
# 1994    74
# 1945    74
# 1970    73
# Name: count, dtype: int64

# %%
#get aircraft type with most crashes
df['AC Type'].value_counts().head(10)
# Out:
# AC Type
# Douglas DC-3                                333
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                70
# Douglas C-47                                 64
# Douglas DC-4                                 38
# Yakovlev YAK-40                              35
# Antonov AN-26                                34
# Junkers JU-52/3m                             31
# De Havilland DH-4                            27
# Douglas C-47B                                27
# Name: count, dtype: int64

# %%
#create a column with number of survivors including those on ground
df['Survivors'] = df['Aboard']-df['Fatalities']-df['Ground']
df.sample(5)
# Out:
#             Date   Time       Location                  Operator Flight #  \
# 879   08/24/1946    NaN          Egypt                   Misrair      NaN
# 2018  03/05/1963  19:35   Turkmenistan                  Aeroflot      191
# 4472  03/04/2004  09:40     Azerbaijan        Azov Avia Airlines      NaN
# 4314  05/17/2001  12:21      Argentina    Fuerza Aérea Argentina      NaN
# 465   07/28/1937  10:40        Belgium  KLM Royal Dutch Airlines      NaN
#
#                          Route                      AC Type Registration  \
# 879                        NaN                   Avro Anson       SU-ADJ
# 2018  \tKrasnovodsk - Ashgabat              Ilyushin IL-18V   CCCP-75765
# 4472     Ankara - Baku - Kabul               Ilyushin II-76       UR-ZVA
# 4314          Mendoza - Parana  Fokker F-27 Friendship 400M        TC-76
# 465          Amsterdam - Paris            Douglas DC-2-115L       PH-ALF
#
#            cn/ln  Aboard  Aboard Passangers  Aboard Crew  Fatalities  \
# ...

# %%
#get me number of crashes with zero survivors
len(df[df['Survivors']==0])
# Out:
# 3017

# %%
plt.figure(figsize=(5,18))
df['Location'].value_counts().head(50).plot(kind='barh')
# Out:
# <Axes: ylabel='Location'>
